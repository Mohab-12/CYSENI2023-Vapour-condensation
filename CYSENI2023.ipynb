# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import matplotlib.animation as animation
# from matplotlib.animation import FuncAnimation, writers

# %%
#sns.set_theme(style='whitegrid', palette='pastel')
plt.style.use('ggplot')

# %%
df=pd.read_excel(r"Horizontalus ruozas-Eksperimetu suvestine.xlsb.xlsx", sheet_name='Sheet3')

# %%
df.drop(columns='Heat lost ', inplace=True)
#df.dropna(inplace=True)

# %%
df['Mixture tin, oC']=df['Mixture tin, oC'].astype('float')

# %%
# df.columns

# %%
a=df.loc[df['Re']==5000][['First_Cond', 'Second_Cond', 'Third_Cond', 'Fourth_Cond',
       'Fifth_Cond', 'Sixth_Cond', 'Seventh_Cond', 'Eighth_Cond','Mixture tin, oC']]
c=df.loc[df['Re']==5000][[ 'First_heat_Coef', 'Second_heat_Coef', 'Third_heat_Coef',
       'Fourth_heat_Coef', 'Fifth_heat_Coef', 'Sixth_heat_Coef',
       'Seventh_heat_Coef', 'Eighth_heat_Coef','Mixture tin, oC']]
e=df.loc[df['Re']==5000][['First_Nusselt', 'Second_Nusselt', 'Third_Nusselt', 'Fourth_Nusselt',
       'Fifth_Nusselt', 'Sixth_Nusselt', 'Seventh_Nusselt', 'Eighth_Nusselt','Mixture tin, oC']]

# %%
Nusselt = e.T
Heat_transfer_coefficient = c.T
Rate_of_Condensation = a.T
Rate_of_Condensation
# Out:
#                     2      3      4      5      6      7      8      9   \
# First_Cond        11.0   11.0   10.0    9.0    5.0    4.0    4.0    3.0
# Second_Cond      641.0  624.0  596.0  573.0  555.0  529.0  505.0  557.0
# Third_Cond        12.0   10.0   20.0    7.0    7.0    5.0    3.0   33.0
# Fourth_Cond      661.0  652.0  606.0  624.0  597.0  600.0  579.0  568.0
# Fifth_Cond        13.0   13.0    8.0    8.0    6.0    6.0    5.0    7.0
# Sixth_Cond       637.0  636.0  623.0  618.0  612.0  620.0  607.0  681.0
# Seventh_Cond      12.0   12.0    9.0    8.0    8.0    7.0    7.0    7.0
# Eighth_Cond      607.0  607.0  592.0  591.0  593.0  584.0  569.0  651.0
# Mixture tin, oC  115.0  125.0  135.0  145.0  155.0  165.0  165.0  185.0
#
#                     10     11  ...     28     29     30     31     32     43  \
# First_Cond         3.0    3.0  ...    6.0    5.0    1.0    0.0    0.0    0.0
# Second_Cond      550.0  574.0  ...  467.0  445.0  417.0  395.0  328.0  443.0
# Third_Cond         3.0    4.0  ...    5.0    4.0    0.0    0.0    0.0    0.0
# Fourth_Cond      640.0  674.0  ...  461.0  451.0  440.0  434.0  399.0  581.0
# Fifth_Cond         5.0    5.0  ...    7.0    7.0    5.0    5.0    0.0    0.0
# Sixth_Cond       661.0  700.0  ...  435.0  431.0  428.0  435.0  400.0  616.0
# Seventh_Cond       9.0    6.0  ...    7.0    6.0    6.0    4.0    0.0    0.0
# Eighth_Cond      633.0  671.0  ...  401.0  405.0  402.0  411.0  383.0  591.0
# Mixture tin, oC  185.0  195.0  ...   85.0  115.0  145.0  175.0  205.0  205.0
#
#                     44     45     46     47
# First_Cond         0.0   23.0    9.0   11.0
# Second_Cond        4.0  513.0  651.0  337.0
# Third_Cond         0.0   21.0   19.0   14.0
# Fourth_Cond      141.0  579.0  712.0  422.0
# Fifth_Cond         0.0   19.0   13.0   11.0
# Sixth_Cond       227.0  544.0  663.0  436.0
# Seventh_Cond       0.0   21.0   13.0   16.0
# Eighth_Cond      283.0  698.0  608.0  442.0
# Mixture tin, oC  205.0   85.0  115.0  115.0
#
# [9 rows x 26 columns]

# %%
import streamlit as st
# df = px.data.gapminder()

st.write("""
            # Plotting parameters against temperature at `Re = 5000` and `mass fraction  = 20%`
            """)
# Out:
# 2023-05-09 09:02:35.249
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Carnival Stores\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
Nusselt.iloc[-1:].values.ravel()
# Out:
# array([115., 125., 135., 145., 155., 165., 165., 185., 185., 195., 205.,
#        215.,  85.,  95., 105., 115.,  85., 115., 145., 175., 205., 205.,
#        205.,  85., 115., 115.])

# %%
import plotly.express as px
import streamlit as st
# df = px.data.gapminder()

T1 = st.sidebar.selectbox(label='Choose a parameter to plot', options=['Nusselt',
                                                                       'Heat transfer coefficient',
                                                                       'Rate of Condensation'])
if T1=='Nusselt':
    T1=Nusselt
    col='Nusselt'
    T2 = st.sidebar.selectbox(label='Choose your Temperature', options=T1.iloc[-1:].values.ravel())
    column_name = T1.columns[T1.eq(T2).any()][0]
    fig = px.line(x = T1.index[:-1], y=T1.iloc[:-1, column_name])
    fig.update_layout(
            xaxis_title=col,
            yaxis_title="Temperature")
    st.write(fig)
elif T1=='Heat transfer coefficient':
    T1=Heat_transfer_coefficient
    col='Heat transfer coefficient'
    T2 = st.sidebar.selectbox(label='Choose your Temperature', options=T1.iloc[-1:].values.ravel())

    column_name = T1.columns[T1.eq(T2).any()][0]
    fig = px.line(x = T1.index[:-1], y=T1.iloc[:-1, column_name])
    fig.update_layout(
            xaxis_title=col,
            yaxis_title="Temperature")
    st.write(fig)
else: 
    T1=Rate_of_Condensation
    col='Rate of condensation'
    T2 = st.sidebar.selectbox(label='Choose your Temperature', options=T1.iloc[-1:].values.ravel())
    column_name = T1.columns[T1.eq(T2).any()][0]
    fig = px.bar(x = T1.index[:-1], y=T1.iloc[:-1, column_name])
    fig.update_layout(
        xaxis_title=col,
        yaxis_title="Temperature")
    st.write(fig)
